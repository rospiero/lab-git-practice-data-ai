# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Piero"
reason = "Future is shaped by AI and I want to get the skills of the future"
fun_fact = "I once stayed up all night trying to fix one bug... and it turned out to be a missing semicolon."
print(f"Hi! My name is {name}. I’m excited to learn because {reason}. A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Piero. I’m excited to learn because Future is shaped by AI and I want to get the skills of the future. A fun fact about me is: I once stayed up all night trying to fix one bug... and it turned out to be a missing semicolon..
